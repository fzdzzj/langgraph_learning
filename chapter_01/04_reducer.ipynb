# %%
def my_reducer(left:list[str],right:list[str])->list[str]:
    return left+right

left = ["start","node_1运行完毕"]
right = ["node_2运行完毕"]
merged = my_reducer(left,right)
print(merged)
# Out:
# ['start', 'node_1运行完毕', 'node_2运行完毕']
